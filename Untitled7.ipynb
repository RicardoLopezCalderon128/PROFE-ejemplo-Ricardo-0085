# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoLopezCalderon128/PROFE-ejemplo-Ricardo-0085/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Lopez Ricardo NL = 29 Fecha 29 Abril   2026
# #### Clase automovil con 3 atributos funciones leerdatos() mostrardatos()
# #### que sea imteractivo --> los input
# #### crear 3 objetos carro1 carro2 carro3
# #### no usar while true if for listas y diccionarios

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/RicardoLopezCalderon128/PROFE-ejemplo-Ricardo-0085/refs/heads/main/infog.png)

# %%
class automovil:
    def __init__(self,marca,placa,precio):
        self.marca=marca
        self.placa=placa
        self.precio=precio

    def leerdatos(self):
        self.marca=input("ingrese la marca del automovil: ")
        self.placa=input("ingrese la placa del automovil: ")
        self.precio=input("ingrese el precio del automovil: ")
        return self.marca,self.placa,self.precio

    def mostrardatos(self):
        print("marca: ",self.marca)
        print("placa: ",self.placa)
        print("precio: ",self.precio)
        return self.marca,self.placa,self.precio
#fin de clase automovil


print("carro numero 1")
carro1 = automovil("", "", "") # creando objeto carro 1 con valores iniciales
carro1.leerdatos()
carro1.mostrardatos()
print("-*-*-*-*-*-*-*-*-*-*-*")
print("carro numero 2")
carro2 = automovil("", "", "") # creando objeto carro 2 con valores iniciales
carro2.leerdatos()
carro2.mostrardatos()
print("-*-*-*-*-*-*-*-*-*-*-*")
print("carro numero 3")
carro3 = automovil("", "", "") # creando objeto carro 3 con valores iniciales
carro3.leerdatos()
carro3.mostrardatos()
print("sofware desarrollado por Ricardo Lopez NL = 29")
# Out:
# carro numero 1
# ingrese la marca del automovil: ford
# ingrese la placa del automovil: 34242
# ingrese el precio del automovil: 8000
# marca:  ford
# placa:  34242
# precio:  8000
# -*-*-*-*-*-*-*-*-*-*-*
# carro numero 2
# ingrese la marca del automovil: nissan
# ingrese la placa del automovil: 464625
# ingrese el precio del automovil: 684848
# marca:  nissan
# placa:  464625
# precio:  684848
# -*-*-*-*-*-*-*-*-*-*-*
# carro numero 3
# ingrese la marca del automovil: isusu
# ingrese la placa del automovil: 414111
# ingrese el precio del automovil: 9889
# marca:  isusu
# placa:  414111
# precio:  9889
# sofware desarrollado por Ricardo Lopez NL = 29

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/RicardoLopezCalderon128/PROFE-ejemplo-Ricardo-0085/refs/heads/main/tldrawprofe.png.png)
